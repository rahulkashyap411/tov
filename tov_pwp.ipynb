# %% [markdown]
# # Imports

# %%
import numpy as np 
import myconstants as const
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
from matplotlib import rc
##from IPython.display import set_matplotlib_formats
##set_matplotlib_formats('svg')
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300
rc('axes', labelsize=20) #24
rc('legend', fontsize=18) #16
rc('xtick', labelsize=14)
rc('ytick', labelsize=14)

import time
from tovlib import *
from scipy.integrate import solve_ivp
#eos_file = './eos_tables/BLH_new_14-Apr-2020.lorene'
#eos_file = './eos_tables/SLy.lorene'

is_sorted = lambda x: (np.diff(x)>=0).all()

def eos_from_pres(pres_in,eos_file='./eos_tables/BLH_new_14-Apr-2020.lorene'):
    
    #if(pres_in.any()<0):
    #    print('pressure input is negative; stop integration and go to previous radial point')
    lg_pres_in = np.log10(pres_in)
    
    fm=1.e-13 #1femotometer in cm
    dens_conversion=const.CGS_AMU/(fm**3)
    edens_conversion=const.CGS_C**2
    
    ds=np.loadtxt(eos_file,comments='#',skiprows=9)
    #rho=ds[:,1]; edens=ds[:,2]; pres=ds[:,3]
    #print('all density > 0? ',all(i >= 0 for i in rho),'; all edens > 0? ',all(i >= 0 for i in edens),'; all pres > 0? ',all(i >= 0 for i in pres))
    #print('is_sorted(rho)? ',is_sorted(rho),'; is_sorted(edens)? ',is_sorted(edens),'; is_sorted(pres) ',is_sorted(pres))

    lg_rho, lg_edens, lg_pres = (np.log10(ds[:,1]),np.log10(ds[:,2]),np.log10(ds[:,3]))

    ind=lg_rho.argsort()                 # sorting mass and other array; necessary for interpolation routine
    sort_ind = ind[::1]
    lg_rho=lg_rho[sort_ind]
    lg_edens=lg_edens[sort_ind]
    lg_pres=lg_pres[sort_ind]
    
    
    #print(is_sorted(rho))
    #dp_dedens_arr=diff(pres)/diff(edens)/edens_conversion
    #dp_dedens_arr = np.insert(dp_dedens_arr, 0, dp_dedens_arr[0], axis=0)

    dlg_p_dlg_edens_arr=np.gradient(lg_pres,lg_edens) #https://numpy.org/doc/stable/reference/generated/numpy.gradient.html
    gamma_arr = dlg_p_dlg_edens_arr
    Gamma_arr=((np.power(10,lg_edens)*edens_conversion+np.power(10,lg_pres))/(np.power(10,lg_edens)*edens_conversion)) * gamma_arr 
    
    rho_out=10**(splev(lg_pres_in,splrep(lg_pres,lg_rho,k=3,s=0)) )
    edens_out=10**(splev(lg_pres_in,splrep(lg_pres,lg_edens,k=3,s=0))) 
    Gamma_out=splev(lg_pres_in,splrep(lg_pres,gamma_arr,k=3,s=0))
    cs_out=np.sqrt((pres_in/edens_out)*(splev(lg_pres_in,splrep(lg_pres,gamma_arr,k=3,s=0))))  #sound speed: sqrt(dpres/dedens) = 
    #gamma_out=5./3.
    return rho_out*dens_conversion, edens_out, Gamma_out, cs_out


def eos_from_dens(rho_in,eos_file='./eos_tables/BLH_new_14-Apr-2020.lorene'):
    
    lg_rho_in = np.log10(rho_in)
    #print(lg_rho_in)
    fm=1.e-13 #1femotometer in cm
    dens_conversion=const.CGS_AMU/(fm**3)
    edens_conversion=const.CGS_C**2
    
    ds=np.loadtxt(eos_file,comments='#',skiprows=9)
    lg_rho, lg_edens, lg_pres = (np.log10(ds[:,1]*dens_conversion),np.log10(ds[:,2]),np.log10(ds[:,3]))
    #print(lg_rho)
    pres_out=10**(splev(lg_rho_in,splrep(lg_rho,lg_pres,k=3,s=0)) )
    edens_out=10**(splev(lg_rho_in,splrep(lg_rho,lg_edens,k=3,s=0))) 
    
    return pres_out, edens_out
###################################################################################3

#for gamma=2 KCGS  = K_{G=c=Msun=1} * (G^3*Msun^2/c^4)
K_scale=const.CGS_G**3 * const.CGS_C**(-4) * const.CGS_MSUN**2
def eos_from_pres_pwp(pres_in):
    K = 123*K_scale
    Γ = 2.
    rho_out = (pres_in/K)**(1./Γ)
    edens_out = rho_out  # no interactions 
    Gamma_out = Γ
    cs_out = np.sqrt(K*Γ*(rho_out**(Γ-1.)))/const.CGS_C
    return(rho_out, edens_out, Gamma_out, cs_out)
    
    
    
def eos_from_dens_pwp(rho_in):
    K = 123*K_scale
    Γ = 2.
    pres_out = K * (rho_in**Γ)
    edens_out = ((pres_out/K)**(1./Γ)) 
    return(pres_out, edens_out)


pres_arr=np.logspace(np.log10(6.e17),np.log10(1.e36),100)
rho_new, edens_out, gamma_new, cs_new = eos_from_pres_pwp(pres_arr)
pres_new, edens_new = eos_from_dens_pwp(rho_new)

#print(cs_new)
n_end=4
colors = iter(cm.rainbow(np.linspace(0, 1,n_end )))  #len(eoslist)

fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(12,12))
color=next(colors)
#print(f'############ {eoskey} ###########')
#eos_file = eos_dir+eoskey+'.lorene'
#eos_tabdata = np.loadtxt(eos_file,comments='#',skiprows=9)
#rho, edens, pres = (eos_tabdata[:,1],eos_tabdata[:,2],eos_tabdata[:,3])
#print(eoskey,'\n####\n',rho,'\n#####\n',edens)
#for p_in in p_new:


#print('is_sorted(edens_new)',is_sorted(edens_new),'is_sorted(rho_new)',is_sorted(rho_new))
#print(f'rho limits: min:{min(rho_new):1.3e}, max={max(rho_new):1.3e}')
ax1.plot(rho_new,pres_arr,c=color, label = 'PWP')
ax1.plot(rho_new,pres_new,'x')
#ax1.set_xlim([1.e14,1.e16])
#ax1.set_ylim([1.e32,1.e36])
ax1.grid(True)
ax1.set(xscale='log',yscale='log',xlabel=r'mass density ($g/cm^{3}$)',ylabel=r'pressure ($dyne/cm^2$)')
ax1.legend(loc=4)

ax2.plot(rho_new,edens_out,c=color, label = 'PWP')
#ax2.set_xlim([1.e14,1.e16])
#ax2.set_ylim([1.e34,1.e37])
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.grid(True)
ax2.set(xlabel=r'mass density ($g/cm^{3}$)',ylabel=r'edens ($g/cm^{3}$)')
ax2.legend(loc=4)


ax4.plot(rho_new,cs_new,c=color,label='PWP, $\Gamma=2$')
ax4.set_yscale('log')
ax4.set_ylim([0.2,1])
ax4.axhline(1/np.sqrt(3),ls='--',c='k',label='conformal limit cs: $c/\sqrt{3}$')
ax4.legend(loc=4)
plt.tight_layout()
print('Γ = ' + str(gamma_new))
#plt.savefig('eos_plots_phase.png',dpi=150)

plt.show()
fig.clf()
# Out:
# Γ = 2.0

# %%
## Root finding by reducing the radial interval and by using scipy.rootfind functions. 
## Works and matches with the MATLAB code.. although there are problems of (1) Speed and (2) accuracy 
from scipy import optimize
#eos_file = './eos_tables/eos4.lorene'
#eos_file = './eos_tables/eos0.lorene'  #eosBHB


def calc_tidal_deformability(C, Y):
    # """ Compute the dimensionless tidal deformability parameter Lambda from the compactness C and 
    # the Lindblom y-potential at the surface of a polytropic star"""
    # Eq.(C1,C2) of Lindblom & Indik 2014
    zeta = 4. * C**3 * (13. - 11.*Y + C*(3.*Y-2.) + 2.*(C**2)*(1.+Y)) + 3. * ((1.-2.*C)**2) * (2. - Y + 2.*C*(Y-1.)) *np.log(1.-2.*C) + 2. * C * (6. - 3.*Y + 3.*C*(5.*Y-8.))
    Lambda_dimensionless = (16./(15.*zeta)) * ((1.-2.*C)**2) * (2. + 2.*C*(Y-1.) - Y)  #dimensionless tidal deformability
    #lambda_dimensional =   Lambda_dimensionless/const.CGS_G *(const.CGS_G*m*const.CGS_MSUN/const.CGS_C**2)**5
    return Lambda_dimensionless

def tov(r,y):

    [P, m, m_baryon, yp] = y
    #if(P<0):
    #    sys.exit()
    #if eos_file != None:
    #P,dummy = eos_from_dens(rhoc,eos_file)
    rho,eden,eos_gamma, cs = eos_from_pres_pwp(P)

    G=const.CGS_G; c=const.CGS_C 

    dPdr = -G*(eden + P/c**2)*(m + 4.0*np.pi*r**3*P/c**2)
    dPdr = dPdr/(r*(r - 2.0*G*m/c**2))
    dmdr = 4.0*np.pi*r**2*eden
    dm_baryondr = dmdr/np.sqrt(1-2*G*m/(r*c**2))
    #G=cgs.G; c=cgs.c

    rho=eden*const.CGS_C**2
    dypdr= -yp**2/r -(r + (G/c**4)*4*np.pi*r**3*(P-rho))*yp/(r*(r-2*G*m/c**2)) + (G**2/c**4)*(4*(m+4*np.pi*r**3*P/c**2)**2)/(r*(r-2*G*m/c**2)**2) + 6/(r-2*const.CGS_G*m/const.CGS_C**2) - 4*np.pi*(r**2)*(5*rho+9*P+(rho+P)**2/(P*eos_gamma))*G/(c**4 * (r-2*G*m/c**2))

    return [dPdr, dmdr, dm_baryondr,dypdr]

def tovsolve(rhoc,r_arr):
    P,dummy = eos_from_dens_pwp(rhoc)
    rho,eden,Gamma,cs = eos_from_pres_pwp(P)
    #print("rho = "+str(rho)+"\n")
    rad_low = r_arr[0]; rad_high = r_arr[-1]
    print(rad_low,rad_high)
    
    rmin = r_arr[0]
    r3=rmin**3
    m = 4./3.*np.pi*r3*eden
    m_baryon = 4./3.*np.pi*r3*eden*(1-2*const.CGS_G*m/(rmin*const.CGS_C**2))**(-0.5)
    yp=2.
    #psol = odeint(tov, [P, m, m_baryon, yp], r_arr, rtol=1.0e-6, atol=1.0e-4,tfirst=True)

    psol = solve_ivp(tov, [rad_low, rad_high] ,[P, m, m_baryon, yp], method='RK45',t_eval=r_arr)
    #print m, m_baryon, rhoc
    #return r_arr, psol[:,0], psol[:,1], psol[:,2], psol[:,3]
    return psol.t, psol.y[0], psol.y[1], psol.y[2], psol.y[3] 


def find_surface(pmin, rhoc, rad_high):
    int_pts=1000
    rad_low=1.e-3
    r_arr = np.linspace(rad_low, rad_high,int_pts)
    #r = np.logspace(-4,6.3,N)

    #star = tovsolve(rhoc,r_arr)

    Pc,dummy = eos_from_dens_pwp(rhoc)
    rhoc,eden_c,Gamma_c,cs_c = eos_from_pres_pwp(Pc)
    #print(f'for pressure in: {Pc:1.2e}, density is {rhoc:1.2e}, edens: {eden_c:1.2e}, Gamma:{Gamma_c} and sound speed: {cs_c:1.2e}')
    rmin = r_arr[0]
    #print(f'rmin:{rmin:1.2e}')
    r3=rmin**3
    m = 4./3.*np.pi*r3*eden_c
    #print('g_00',np.sqrt(1-2*const.CGS_G*m/(rmin*const.CGS_C**2)))
    m_baryon = m/np.sqrt(1-2*const.CGS_G*m/(rmin*const.CGS_C**2))
    yp=2.
    
    var_vec=[Pc, m, m_baryon, yp]
    
    #psol = odeint(tov, var_vec, r_arr, rtol=1.0e-6, atol=1.0e-4,tfirst=True)
    #end_pres = psol[:,0][-1]
    #return end_pres-pmin

    psol = solve_ivp(tov, [rad_low, rad_high] ,var_vec, method='RK45')
    #print(psol.y[0][-1])
    return psol.y[0][-1]-pmin
    ############################

    
    
    
###
time1=time.time()

#######################################################3
pmin=1.e12#1.e-12
len_seq=100
rhoc_arr=np.logspace(np.log10(5.e14),np.log10(2.e15),len_seq)
rad_high = 5.e6
rad_seq=[];mg_seq=[];mb_seq=[];lambda_seq=[]
for rhoc in rhoc_arr:
    rad_low = 1.e-3
    int_pts=2000
    r_arr = np.linspace(rad_low, rad_high,int_pts)
    psol = tovsolve(rhoc,r_arr)
    #print(psol)
    #rhoc=4.e14 #cgs
    rstar = optimize.brentq(lambda rad_high: find_surface(pmin,rhoc,rad_high), 6.e5, 3.e6,rtol=1.e-4)
    #rstar = optimize.bisect(lambda rad_high: find_surface(pmin,rhoc,rad_high), 6.e5, 3.e6,rtol=1.e-5)
    
    #print(rstar/1.e5)

    time4= time.time()
    print('time elapsed in root finding:',time4-time1)

    rad_low = 1.e-3; rad_high = rstar
    int_pts=2000
    r_arr = np.linspace(rad_low, rad_high,int_pts)
    #r = np.logspace(-4,6.3,N)

    #star = tovsolve(rhoc,r_arr)

    Pc,dummy = eos_from_dens_pwp(rhoc)
    rhoc,eden_c,Gamma_c,cs_c = eos_from_pres_pwp(Pc)
    print(f'for pressure in: {Pc:1.2e}, density is {rhoc:1.2e}, edens: {eden_c:1.2e}, Gamma:{Gamma_c} and sound speed: {cs_c:1.2e}')
    rmin = r_arr[0]
    #print(f'rmin:{rmin:1.2e}')
    r3=rmin**3
    m = 4./3.*np.pi*r3*eden_c
    #print('g_00',np.sqrt(1-2*const.CGS_G*m/(rmin*const.CGS_C**2)))
    m_baryon = m/np.sqrt(1-2*const.CGS_G*m/(rmin*const.CGS_C**2))
    yp=2.
    psol = solve_ivp(tov, [rad_low, rad_high] ,[Pc, m, m_baryon, yp], method='RK45') #,t_eval=r_arr)
    [P, m, m_baryon, yp] = [psol.y[0][-1], psol.y[1][-1], psol.y[2][-1], psol.y[3][-1]]

    print(f'FINAL: rstar: {rstar/1.e5:1.2f}, grav. mass: {m/const.CGS_MSUN:1.2f}, bary. mass: {m_baryon/const.CGS_MSUN:1.2f}, yp: {yp}')
    C=(const.CGS_G/const.CGS_C**2)*m/rstar
    print(C)
    lambda_dimensionless = calc_tidal_deformability(C,yp)
    
    rad_seq.append(rstar/1.e5); mg_seq.append(m/const.CGS_MSUN); mb_seq.append(m_baryon/const.CGS_MSUN); lambda_seq.append(lambda_dimensionless)
    
    ##
time2 = time.time()
print('time elapsed:',time2-time4)

tov_data={'rad':np.array(rad_seq),'mg':np.array(mg_seq), 'mb':np.array(mb_seq),'lambda':np.array(lambda_seq)}

print(tov_data)

np.savetxt('tov_seq_pwp2.dat',np.c_[rad_seq,mg_seq,mb_seq,lambda_seq],header='\n#rad,mg,mb,lambda',comments='#Solution of tov with pwp gam=2\n')

"""
#######################################################
time2 = time.time()
#rhoc=3.e14 # cgs   

def get_tovStar(rhoc):
    rad_low=1.e-3
    rad_high=3.e6 
    int_pts=60
    r_arr = np.linspace(rad_low, rad_high,int_pts)
    
    Pc,dummy = eos_from_dens(rhoc,eos_file)
    rhoc,eden_c,Gamma_c,cs_c = eos_from_pres(Pc,eos_file)
    print(f'for central pressure: {Pc:1.2e}, density ={rhoc:1.2e}, edens = {eden_c:1.2e}, Gamma = {Gamma_c} and sound speed = {cs_c:1.2e}')
    rmin = r_arr[0]
    #print(f'rmin:{rmin:1.2e}')
    r3=rmin**3
    m = 4./3.*np.pi*r3*eden_c
    #print('g_00',np.sqrt(1-2*const.CGS_G*m/(rmin*const.CGS_C**2)))
    m_baryon = m/np.sqrt(1-2*const.CGS_G*m/(rmin*const.CGS_C**2))
    yp=2.
    y_new=[Pc, m, m_baryon, yp]
    pmin=1.e-12 #Pc*1.e-11
    print(f'minimum pressure to reach is = {pmin:1.2e}')

    eps_rad=1000 #cm
    dr=r_arr[1]-r_arr[0]
    
    eps_pres = 1.e-12; eps_mass = 1.e20; eps_yp = 1.e-6 
    for i,r in enumerate(r_arr):
        y_old = y_new
        tst_solvivp = time.time()
        psol = solve_ivp(tov, [r, r+dr] ,y_old, method='RK45',atol=[eps_pres,eps_mass,eps_mass,eps_yp],rtol=1.e-3)
        ten_solvivp = time.time()
        print(f'time per solve_ivp:{ten_solvivp-tst_solvivp}')
        [P, m, m_baryon, yp] = [psol.y[0][-1], psol.y[1][-1], psol.y[2][-1], psol.y[3][-1]]
        y_new = [P, m, m_baryon, yp]
        #print(f'NEW: pressure: {P:1.2e}, grav. mass: {m:1.2e}, bary. mass: {m_baryon:1.2e}, yp: {yp}')

        if(P<pmin):
            n=int(dr/eps_rad)
            #print(r,dr,n)
            rad_arr = np.linspace(r,r+dr,n)

            ddr = rad_arr[1]-rad_arr[0]
            y_new2 = y_old
            for r in rad_arr:
                y_old = y_new2
                tst_solvivp = time.time()
                psol = solve_ivp(tov, [r, r+ddr] ,y_old, method='RK45',atol=[eps_pres,eps_mass,eps_mass,eps_yp],rtol=1.e-3)
                ten_solvivp = time.time()
                print(f'time per solve_ivp (finer grid):{ten_solvivp-tst_solvivp}')
                [P, m, m_baryon, yp] = [psol.y[0][-1], psol.y[1][-1], psol.y[2][-1], psol.y[3][-1]]
                y_new2 = [P, m, m_baryon, yp]
                if(P<pmin):       
                    [P, m, m_baryon, yp] = y_old
                    #print(f'radius: {r/1.e5} km, mass: {m/const.CGS_MSUN} solar mass')
                    print(f'Final: pressure: {P:1.2e}, rhoc:{rhoc:1.2e} radius: {r/1.e5} km, grav. mass: {m/const.CGS_MSUN:1.2f}, bary. mass: {m_baryon/const.CGS_MSUN:1.2f}, yp: {yp}')
                    break
            
            break
            
        #else:
            #print(f'did not reach pmin={pmin:1.2e} for eos={eos_file}')
    C=(G/c**2)*m/r
    lambda_dimensionless = calc_tidal_deformability(C,yp)
    return C, m_baryon/const.CGS_MSUN, m/const.CGS_MSUN, r/1.e5, lambda_dimensionless


len_seq=5
rhoc_arr=np.logspace(np.log10(6.e14),np.log10(3.e15),len_seq)

tov_data=[]
for rhoc in rhoc_arr:
    C,mb,mg,r,lam = get_tovStar(rhoc) 
    tov_data.append([C,mb,mg,r,lam])


print(tov_data)



time3 = time.time()
print('time elapsed in loops:',time3-time2)
"""



################################################
"""for i,r in enumerate(r_arr):
    #print(f'iteration:{i}, radial coordinate: {r_arr[i]}')

    y_old = y_new
    #[P, m, m_baryon, yp] = y_old
    #print(f'OLD: pressure: {P:1.2e}, grav. mass: {m:1.2e}, bary. mass: {m_baryon:1.2e}, yp: {yp}')
    dr=r_arr[i+1]-r_arr[i]
    #print(f'dr: {dr:1.2e}')
    #print(tov(y,r))
    [dPdr, dmdr, dm_baryondr,dypdr] = tov(r,y_old)
    #print(f'dPdr:{dPdr:1.2e},dmdr:{dmdr:1.2e},dm_baryondr:{dm_baryondr:1.2e},dypdr:{dypdr:1.2e}')
    #print(dr*np.array([dPdr, dmdr, dm_baryondr,dypdr]))
    y_new=y_old+dr*np.array([dPdr, dmdr, dm_baryondr,dypdr])
    [P, m, m_baryon, yp] = y_new
    #print(f'NEW: pressure: {P:1.2e}, grav. mass: {m:1.2e}, bary. mass: {m_baryon:1.2e}, yp: {yp}')

    pmin=Pc*1.e-11
    if(P<pmin):
        print(f'radius: {r/1.e5} km, mass: {m/const.CGS_MSUN} solar mass')
        sys.exit()"""
# Out:
# 0.001 5000000.0
# /home/rkashyap/sw/anaconda3/envs/gw_py377/lib/python3.7/site-packages/ipykernel_launcher.py:87: RuntimeWarning: invalid value encountered in double_scalars
# time elapsed in root finding: 2.6116840839385986
# for pressure in: 4.47e+34, density is 5.00e+14, edens: 5.00e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.99, grav. mass: 1.55, bary. mass: 1.74, yp: 0.6688165116878148
# 0.13436223018903373
# 0.001 1699076.943673642
# time elapsed in root finding: 4.430780649185181
# for pressure in: 4.60e+34, density is 5.07e+14, edens: 5.07e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.95, grav. mass: 1.56, bary. mass: 1.75, yp: 0.6739615318611389
# 0.1356188215716978
# 0.001 1695264.4990197602
# time elapsed in root finding: 6.3988001346588135
# for pressure in: 4.73e+34, density is 5.14e+14, edens: 5.14e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.92, grav. mass: 1.57, bary. mass: 1.77, yp: 0.6792192318540573
# 0.13686734329034764
# 0.001 1691613.3087815747
# time elapsed in root finding: 8.2646484375
# for pressure in: 4.87e+34, density is 5.21e+14, edens: 5.21e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.88, grav. mass: 1.58, bary. mass: 1.78, yp: 0.6844437724721352
# 0.1381457450085022
# 0.001 1687779.7126972547
# time elapsed in root finding: 10.07749056816101
# for pressure in: 5.01e+34, density is 5.29e+14, edens: 5.29e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.84, grav. mass: 1.59, bary. mass: 1.80, yp: 0.6896796766346744
# 0.1394154722052008
# 0.001 1684066.599708092
# time elapsed in root finding: 11.525948286056519
# for pressure in: 5.15e+34, density is 5.36e+14, edens: 5.36e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.80, grav. mass: 1.60, bary. mass: 1.81, yp: 0.6951696459198363
# 0.14069013947123252
# 0.001 1680182.9216182702
# time elapsed in root finding: 13.34216856956482
# for pressure in: 5.29e+34, density is 5.44e+14, edens: 5.44e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.76, grav. mass: 1.61, bary. mass: 1.83, yp: 0.7004074142550317
# 0.1419723830310527
# 0.001 1676435.5944081433
# time elapsed in root finding: 15.314933776855469
# for pressure in: 5.44e+34, density is 5.51e+14, edens: 5.51e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.72, grav. mass: 1.62, bary. mass: 1.84, yp: 0.7066857622997197
# 0.14322464196462162
# 0.001 1672353.2068706602
# time elapsed in root finding: 17.819633960723877
# for pressure in: 5.60e+34, density is 5.59e+14, edens: 5.59e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.69, grav. mass: 1.63, bary. mass: 1.85, yp: 0.7115613685494998
# 0.1445427004061689
# 0.001 1668696.6871235939
# time elapsed in root finding: 20.292037963867188
# for pressure in: 5.76e+34, density is 5.67e+14, edens: 5.67e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.65, grav. mass: 1.64, bary. mass: 1.87, yp: 0.7179454456265567
# 0.14579938492966937
# 0.001 1664639.8664970924
# time elapsed in root finding: 23.144906520843506
# for pressure in: 5.92e+34, density is 5.75e+14, edens: 5.75e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.61, grav. mass: 1.65, bary. mass: 1.88, yp: 0.7233591678945228
# 0.14712475438446218
# 0.001 1660708.9745869571
# time elapsed in root finding: 25.05061149597168
# for pressure in: 6.09e+34, density is 5.83e+14, edens: 5.83e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.57, grav. mass: 1.67, bary. mass: 1.90, yp: 0.7292494299014489
# 0.1484229600789805
# 0.001 1656720.9906538336
# time elapsed in root finding: 26.908915281295776
# for pressure in: 6.26e+34, density is 5.91e+14, edens: 5.91e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.53, grav. mass: 1.68, bary. mass: 1.91, yp: 0.7351026369668714
# 0.14972136650086748
# 0.001 1652848.114155937
# time elapsed in root finding: 28.805482864379883
# for pressure in: 6.44e+34, density is 6.00e+14, edens: 6.00e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.49, grav. mass: 1.69, bary. mass: 1.93, yp: 0.7405127370326169
# 0.1510550830190235
# 0.001 1648951.3941342174
# time elapsed in root finding: 30.45119857788086
# for pressure in: 6.62e+34, density is 6.08e+14, edens: 6.08e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.45, grav. mass: 1.70, bary. mass: 1.94, yp: 0.7465376831042856
# 0.15237263633023762
# 0.001 1644884.1711294698
# time elapsed in root finding: 32.28331232070923
# for pressure in: 6.81e+34, density is 6.17e+14, edens: 6.17e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.41, grav. mass: 1.71, bary. mass: 1.96, yp: 0.7525852360135632
# 0.15369226216607268
# 0.001 1640852.3713486744
# time elapsed in root finding: 34.06693458557129
# for pressure in: 7.00e+34, density is 6.26e+14, edens: 6.26e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.37, grav. mass: 1.72, bary. mass: 1.97, yp: 0.7586937461426309
# 0.15500695878742524
# 0.001 1636901.6202968918
# time elapsed in root finding: 36.16411852836609
# for pressure in: 7.20e+34, density is 6.34e+14, edens: 6.34e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.33, grav. mass: 1.73, bary. mass: 1.99, yp: 0.7650233457238778
# 0.15633239380308847
# 0.001 1632795.5834251922
# time elapsed in root finding: 38.01996731758118
# for pressure in: 7.41e+34, density is 6.43e+14, edens: 6.43e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.29, grav. mass: 1.74, bary. mass: 2.00, yp: 0.7712311680225519
# 0.15766257484925492
# 0.001 1628678.6363400044
# time elapsed in root finding: 40.003252267837524
# for pressure in: 7.62e+34, density is 6.52e+14, edens: 6.52e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.24, grav. mass: 1.75, bary. mass: 2.02, yp: 0.7778069050117071
# 0.15899747257576313
# 0.001 1624430.5979276714
# time elapsed in root finding: 41.981860399246216
# for pressure in: 7.83e+34, density is 6.62e+14, edens: 6.62e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.20, grav. mass: 1.76, bary. mass: 2.03, yp: 0.7839589437140602
# 0.16034368413920155
# 0.001 1620370.3581443154
# time elapsed in root finding: 45.16010332107544
# for pressure in: 8.06e+34, density is 6.71e+14, edens: 6.71e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.16, grav. mass: 1.77, bary. mass: 2.05, yp: 0.790715157061586
# 0.1616676845192422
# 0.001 1616113.548135785
# time elapsed in root finding: 47.62273406982422
# for pressure in: 8.29e+34, density is 6.80e+14, edens: 6.80e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.12, grav. mass: 1.78, bary. mass: 2.06, yp: 0.7976513620855001
# 0.16300087114116468
# 0.001 1611816.2243758077
# time elapsed in root finding: 50.216559171676636
# for pressure in: 8.52e+34, density is 6.90e+14, edens: 6.90e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.08, grav. mass: 1.79, bary. mass: 2.08, yp: 0.803895279691612
# 0.16435102712981586
# 0.001 1607802.824775728
# time elapsed in root finding: 52.61975145339966
# for pressure in: 8.76e+34, density is 7.00e+14, edens: 7.00e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 16.03, grav. mass: 1.80, bary. mass: 2.09, yp: 0.8106959234701299
# 0.16570172629321173
# 0.001 1603477.0974977617
# time elapsed in root finding: 55.804957151412964
# for pressure in: 9.01e+34, density is 7.10e+14, edens: 7.10e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.99, grav. mass: 1.81, bary. mass: 2.10, yp: 0.8177409284502792
# 0.16703993108075915
# 0.001 1599224.8501308237
# time elapsed in root finding: 57.764260053634644
# for pressure in: 9.27e+34, density is 7.20e+14, edens: 7.20e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.95, grav. mass: 1.82, bary. mass: 2.12, yp: 0.8245019343710782
# 0.16838819389920287
# 0.001 1595016.320382265
# time elapsed in root finding: 60.48682475090027
# for pressure in: 9.53e+34, density is 7.30e+14, edens: 7.30e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.91, grav. mass: 1.83, bary. mass: 2.13, yp: 0.8315664341462419
# 0.16974925816707512
# 0.001 1590643.3660760326
# time elapsed in root finding: 63.376182556152344
# for pressure in: 9.80e+34, density is 7.40e+14, edens: 7.40e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.86, grav. mass: 1.84, bary. mass: 2.15, yp: 0.8387338994055761
# 0.17109275950371172
# 0.001 1586302.2833187936
# time elapsed in root finding: 65.69212603569031
# for pressure in: 1.01e+35, density is 7.50e+14, edens: 7.50e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.82, grav. mass: 1.85, bary. mass: 2.16, yp: 0.8458095197932447
# 0.17245709559014072
# 0.001 1581979.446989403
# time elapsed in root finding: 67.6144962310791
# for pressure in: 1.04e+35, density is 7.61e+14, edens: 7.61e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.78, grav. mass: 1.86, bary. mass: 2.18, yp: 0.853108216845219
# 0.17381035590491048
# 0.001 1577584.7802122473
# time elapsed in root finding: 70.26844668388367
# for pressure in: 1.07e+35, density is 7.72e+14, edens: 7.72e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.73, grav. mass: 1.87, bary. mass: 2.19, yp: 0.8607097830875652
# 0.17515495615674917
# 0.001 1573214.3037524729
# time elapsed in root finding: 72.66084313392639
# for pressure in: 1.10e+35, density is 7.83e+14, edens: 7.83e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.69, grav. mass: 1.88, bary. mass: 2.21, yp: 0.8680859458303305
# 0.17651782482392497
# 0.001 1568814.5962263388
# time elapsed in root finding: 74.66762185096741
# for pressure in: 1.13e+35, density is 7.94e+14, edens: 7.94e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.64, grav. mass: 1.88, bary. mass: 2.22, yp: 0.8755355514297892
# 0.17788353142343394
# 0.001 1564386.6995480037
# time elapsed in root finding: 76.66969060897827
# for pressure in: 1.16e+35, density is 8.05e+14, edens: 8.05e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.60, grav. mass: 1.89, bary. mass: 2.23, yp: 0.8831056545412714
# 0.17923601237079362
# 0.001 1559978.631148753
# time elapsed in root finding: 80.07512760162354
# for pressure in: 1.19e+35, density is 8.16e+14, edens: 8.16e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.55, grav. mass: 1.90, bary. mass: 2.25, yp: 0.8908033543684373
# 0.18060215967254734
# 0.001 1555474.7302072747
# time elapsed in root finding: 82.18731641769409
# for pressure in: 1.23e+35, density is 8.28e+14, edens: 8.28e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.51, grav. mass: 1.91, bary. mass: 2.26, yp: 0.8986167459597627
# 0.1819552048379384
# 0.001 1551056.1471794392
# time elapsed in root finding: 84.00910949707031
# for pressure in: 1.26e+35, density is 8.39e+14, edens: 8.39e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.46, grav. mass: 1.92, bary. mass: 2.28, yp: 0.906463461873796
# 0.18332587289129984
# 0.001 1546498.0463591828
# time elapsed in root finding: 85.65768623352051
# for pressure in: 1.30e+35, density is 8.51e+14, edens: 8.51e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.42, grav. mass: 1.93, bary. mass: 2.29, yp: 0.9147031811303488
# 0.18468457822013457
# 0.001 1541900.5877042755
# time elapsed in root finding: 87.48128986358643
# for pressure in: 1.33e+35, density is 8.63e+14, edens: 8.63e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.38, grav. mass: 1.94, bary. mass: 2.30, yp: 0.9226884487757057
# 0.18603301566454333
# 0.001 1537525.6361073973
# time elapsed in root finding: 89.64723324775696
# for pressure in: 1.37e+35, density is 8.75e+14, edens: 8.75e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.33, grav. mass: 1.95, bary. mass: 2.32, yp: 0.9306643513576707
# 0.18739957598563425
# 0.001 1532986.640601988
# time elapsed in root finding: 91.55025315284729
# for pressure in: 1.41e+35, density is 8.88e+14, edens: 8.88e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.28, grav. mass: 1.95, bary. mass: 2.33, yp: 0.9388627050578863
# 0.18876958393887971
# 0.001 1528366.5137903003
# time elapsed in root finding: 93.28414368629456
# for pressure in: 1.45e+35, density is 9.00e+14, edens: 9.00e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.24, grav. mass: 1.96, bary. mass: 2.34, yp: 0.9472724513791025
# 0.19012946048849047
# 0.001 1523802.5150207551
# time elapsed in root finding: 94.99830317497253
# for pressure in: 1.49e+35, density is 9.13e+14, edens: 9.13e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.19, grav. mass: 1.97, bary. mass: 2.36, yp: 0.9559685907634684
# 0.19147581079827727
# 0.001 1519146.4170851742
# time elapsed in root finding: 96.64051151275635
# for pressure in: 1.53e+35, density is 9.26e+14, edens: 9.26e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.14, grav. mass: 1.98, bary. mass: 2.37, yp: 0.9644809132005102
# 0.1928408400216225
# 0.001 1514487.4797991863
# time elapsed in root finding: 98.40420699119568
# for pressure in: 1.58e+35, density is 9.39e+14, edens: 9.39e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.10, grav. mass: 1.99, bary. mass: 2.39, yp: 0.9727027647808555
# 0.19420504153906548
# 0.001 1509976.1814691245
# time elapsed in root finding: 100.1195867061615
# for pressure in: 1.62e+35, density is 9.52e+14, edens: 9.52e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.05, grav. mass: 1.99, bary. mass: 2.40, yp: 0.9814135158859972
# 0.1955513771243585
# 0.001 1505410.5127268196
# time elapsed in root finding: 101.74849081039429
# for pressure in: 1.67e+35, density is 9.66e+14, edens: 9.66e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 15.01, grav. mass: 2.00, bary. mass: 2.41, yp: 0.9902716295791804
# 0.19690473927883434
# 0.001 1500739.6809645514
# time elapsed in root finding: 103.281076669693
# for pressure in: 1.72e+35, density is 9.79e+14, edens: 9.79e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.96, grav. mass: 2.01, bary. mass: 2.42, yp: 0.999071606174108
# 0.19826606090702548
# 0.001 1496044.6725804717
# time elapsed in root finding: 105.1284670829773
# for pressure in: 1.76e+35, density is 9.93e+14, edens: 9.93e+14, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.91, grav. mass: 2.02, bary. mass: 2.44, yp: 1.008048741650603
# 0.19961625335993732
# 0.001 1491374.9800779012
# time elapsed in root finding: 107.01183772087097
# for pressure in: 1.82e+35, density is 1.01e+15, edens: 1.01e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.87, grav. mass: 2.02, bary. mass: 2.45, yp: 1.017515492906021
# 0.2009496555676869
# 0.001 1486640.267127164
# time elapsed in root finding: 108.69274044036865
# for pressure in: 1.87e+35, density is 1.02e+15, edens: 1.02e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.82, grav. mass: 2.03, bary. mass: 2.46, yp: 1.0262903625742272
# 0.2023089643912725
# 0.001 1482008.0050467062
# time elapsed in root finding: 110.67318940162659
# for pressure in: 1.92e+35, density is 1.04e+15, edens: 1.04e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.77, grav. mass: 2.04, bary. mass: 2.48, yp: 1.0355553778298847
# 0.20365477135214535
# 0.001 1477278.2720366328
# time elapsed in root finding: 112.63442158699036
# for pressure in: 1.97e+35, density is 1.05e+15, edens: 1.05e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.72, grav. mass: 2.04, bary. mass: 2.49, yp: 1.0450969486146418
# 0.20499131541861537
# 0.001 1472485.0598236886
# time elapsed in root finding: 114.56187272071838
# for pressure in: 2.03e+35, density is 1.07e+15, edens: 1.07e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.68, grav. mass: 2.05, bary. mass: 2.50, yp: 1.0544754254900668
# 0.20632819857712004
# 0.001 1467808.2222478664
# time elapsed in root finding: 116.41602206230164
# for pressure in: 2.09e+35, density is 1.08e+15, edens: 1.08e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.63, grav. mass: 2.06, bary. mass: 2.51, yp: 1.063946971752002
# 0.20765799438676705
# 0.001 1463152.0353243016
# time elapsed in root finding: 118.48962736129761
# for pressure in: 2.15e+35, density is 1.10e+15, edens: 1.10e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.58, grav. mass: 2.06, bary. mass: 2.53, yp: 1.0737635157816612
# 0.20898620909564716
# 0.001 1458359.0573686322
# time elapsed in root finding: 120.5175793170929
# for pressure in: 2.21e+35, density is 1.11e+15, edens: 1.11e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.54, grav. mass: 2.07, bary. mass: 2.54, yp: 1.0833401603607593
# 0.21032137152437433
# 0.001 1453621.8978229987
# time elapsed in root finding: 122.2124879360199
# for pressure in: 2.27e+35, density is 1.13e+15, edens: 1.13e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.49, grav. mass: 2.08, bary. mass: 2.55, yp: 1.0932452942662672
# 0.21165292878159458
# 0.001 1448757.406581422
# time elapsed in root finding: 124.06177830696106
# for pressure in: 2.34e+35, density is 1.14e+15, edens: 1.14e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.44, grav. mass: 2.08, bary. mass: 2.56, yp: 1.103169592560868
# 0.21297310060726393
# 0.001 1443995.9675548347
# time elapsed in root finding: 126.10338521003723
# for pressure in: 2.40e+35, density is 1.16e+15, edens: 1.16e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.39, grav. mass: 2.09, bary. mass: 2.57, yp: 1.1131636857871026
# 0.21428759164615874
# 0.001 1439272.086161917
# time elapsed in root finding: 127.88417196273804
# for pressure in: 2.47e+35, density is 1.17e+15, edens: 1.17e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.34, grav. mass: 2.09, bary. mass: 2.59, yp: 1.1233484338975908
# 0.21560814834567604
# 0.001 1434381.2439613845
# time elapsed in root finding: 129.2725636959076
# for pressure in: 2.54e+35, density is 1.19e+15, edens: 1.19e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.30, grav. mass: 2.10, bary. mass: 2.60, yp: 1.1337736003774515
# 0.21691395696306293
# 0.001 1429556.6648319596
# time elapsed in root finding: 130.46769738197327
# for pressure in: 2.61e+35, density is 1.21e+15, edens: 1.21e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.25, grav. mass: 2.11, bary. mass: 2.61, yp: 1.14399791965629
# 0.21822227928362478
# 0.001 1424734.7072805022
# time elapsed in root finding: 131.99386954307556
# for pressure in: 2.69e+35, density is 1.23e+15, edens: 1.23e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.20, grav. mass: 2.11, bary. mass: 2.62, yp: 1.1543377262654893
# 0.21951970869895304
# 0.001 1419970.642043658
# time elapsed in root finding: 134.1748161315918
# for pressure in: 2.76e+35, density is 1.24e+15, edens: 1.24e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.15, grav. mass: 2.12, bary. mass: 2.63, yp: 1.164871835400454
# 0.2208159556865743
# 0.001 1415136.7549736388
# time elapsed in root finding: 136.16343069076538
# for pressure in: 2.84e+35, density is 1.26e+15, edens: 1.26e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.10, grav. mass: 2.12, bary. mass: 2.64, yp: 1.1754928236196285
# 0.22210464134996566
# 0.001 1410321.3952903245
# time elapsed in root finding: 138.02479815483093
# for pressure in: 2.92e+35, density is 1.28e+15, edens: 1.28e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.06, grav. mass: 2.13, bary. mass: 2.65, yp: 1.1862125359195896
# 0.22339152063751486
# 0.001 1405529.3310653267
# time elapsed in root finding: 140.26310348510742
# for pressure in: 3.00e+35, density is 1.30e+15, edens: 1.30e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 14.01, grav. mass: 2.13, bary. mass: 2.66, yp: 1.1970074151028423
# 0.22467938289718464
# 0.001 1400656.886116492
# time elapsed in root finding: 142.11633372306824
# for pressure in: 3.09e+35, density is 1.31e+15, edens: 1.31e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.96, grav. mass: 2.14, bary. mass: 2.67, yp: 1.2079306138935961
# 0.22595408860545574
# 0.001 1395759.9608978585
# time elapsed in root finding: 144.40940070152283
# for pressure in: 3.18e+35, density is 1.33e+15, edens: 1.33e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.91, grav. mass: 2.14, bary. mass: 2.69, yp: 1.218902415076444
# 0.22721215824028357
# 0.001 1391008.5992616457
# time elapsed in root finding: 146.55919456481934
# for pressure in: 3.27e+35, density is 1.35e+15, edens: 1.35e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.86, grav. mass: 2.14, bary. mass: 2.70, yp: 1.2301706589858958
# 0.22847623495384678
# 0.001 1386150.017890052
# time elapsed in root finding: 148.6904366016388
# for pressure in: 3.36e+35, density is 1.37e+15, edens: 1.37e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.81, grav. mass: 2.15, bary. mass: 2.71, yp: 1.2410785493221674
# 0.22975325243422556
# 0.001 1381302.2973097125
# time elapsed in root finding: 150.6163432598114
# for pressure in: 3.46e+35, density is 1.39e+15, edens: 1.39e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.76, grav. mass: 2.15, bary. mass: 2.72, yp: 1.252519051439484
# 0.2309909230489779
# 0.001 1376434.8986333937
# time elapsed in root finding: 153.26123046875
# for pressure in: 3.55e+35, density is 1.41e+15, edens: 1.41e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.72, grav. mass: 2.16, bary. mass: 2.73, yp: 1.2638765593776304
# 0.23223821417480986
# 0.001 1371566.8617582298
# time elapsed in root finding: 156.2504312992096
# for pressure in: 3.66e+35, density is 1.43e+15, edens: 1.43e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.67, grav. mass: 2.16, bary. mass: 2.74, yp: 1.2753498611478071
# 0.23347855783756935
# 0.001 1366726.8899707508
# time elapsed in root finding: 159.12474656105042
# for pressure in: 3.76e+35, density is 1.45e+15, edens: 1.45e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.62, grav. mass: 2.16, bary. mass: 2.75, yp: 1.2869115610822663
# 0.2347197617723727
# 0.001 1361837.9199535784
# time elapsed in root finding: 161.53268480300903
# for pressure in: 3.87e+35, density is 1.47e+15, edens: 1.47e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.57, grav. mass: 2.17, bary. mass: 2.75, yp: 1.2985520654892604
# 0.23594496471659215
# 0.001 1356992.8882341152
# time elapsed in root finding: 163.2408196926117
# for pressure in: 3.98e+35, density is 1.49e+15, edens: 1.49e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.52, grav. mass: 2.17, bary. mass: 2.76, yp: 1.3102712475266778
# 0.23716423978689702
# 0.001 1352137.4822194444
# time elapsed in root finding: 164.79534125328064
# for pressure in: 4.09e+35, density is 1.51e+15, edens: 1.51e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.47, grav. mass: 2.17, bary. mass: 2.77, yp: 1.3220994963063228
# 0.23837316302421177
# 0.001 1347315.3019897616
# time elapsed in root finding: 166.92089581489563
# for pressure in: 4.21e+35, density is 1.53e+15, edens: 1.53e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.42, grav. mass: 2.18, bary. mass: 2.78, yp: 1.3340405454936346
# 0.2395880186387636
# 0.001 1342438.6756199368
# time elapsed in root finding: 168.61406111717224
# for pressure in: 4.32e+35, density is 1.55e+15, edens: 1.55e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.38, grav. mass: 2.18, bary. mass: 2.79, yp: 1.3460419186870782
# 0.2407871549138877
# 0.001 1337563.3480472413
# time elapsed in root finding: 170.38190007209778
# for pressure in: 4.45e+35, density is 1.58e+15, edens: 1.58e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.33, grav. mass: 2.18, bary. mass: 2.80, yp: 1.3581387351296563
# 0.2419798719805234
# 0.001 1332746.6309539126
# time elapsed in root finding: 172.8249969482422
# for pressure in: 4.57e+35, density is 1.60e+15, edens: 1.60e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.28, grav. mass: 2.19, bary. mass: 2.81, yp: 1.3703116814972909
# 0.24315967552976292
# 0.001 1327907.3195498786
# time elapsed in root finding: 174.90610456466675
# for pressure in: 4.70e+35, density is 1.62e+15, edens: 1.62e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.23, grav. mass: 2.19, bary. mass: 2.82, yp: 1.382588264627267
# 0.24433892942453397
# 0.001 1323049.4289124124
# time elapsed in root finding: 176.77827620506287
# for pressure in: 4.84e+35, density is 1.64e+15, edens: 1.64e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.18, grav. mass: 2.19, bary. mass: 2.83, yp: 1.3949313584401972
# 0.24550779488397664
# 0.001 1318230.635227908
# time elapsed in root finding: 179.10495829582214
# for pressure in: 4.97e+35, density is 1.67e+15, edens: 1.67e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.13, grav. mass: 2.19, bary. mass: 2.83, yp: 1.4073774321512977
# 0.24665901747358235
# 0.001 1313441.9543300176
# time elapsed in root finding: 181.16766023635864
# for pressure in: 5.12e+35, density is 1.69e+15, edens: 1.69e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.09, grav. mass: 2.20, bary. mass: 2.84, yp: 1.419885681487195
# 0.2478094314558284
# 0.001 1308651.5266997106
# time elapsed in root finding: 183.20634198188782
# for pressure in: 5.26e+35, density is 1.71e+15, edens: 1.71e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 13.04, grav. mass: 2.20, bary. mass: 2.85, yp: 1.432494075834329
# 0.24894918565284357
# 0.001 1303843.5620922688
# time elapsed in root finding: 185.5131185054779
# for pressure in: 5.41e+35, density is 1.74e+15, edens: 1.74e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.99, grav. mass: 2.20, bary. mass: 2.86, yp: 1.4451791430583456
# 0.2500843375737708
# 0.001 1299044.2053303623
# time elapsed in root finding: 187.7830789089203
# for pressure in: 5.56e+35, density is 1.76e+15, edens: 1.76e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.94, grav. mass: 2.20, bary. mass: 2.86, yp: 1.4579411763363979
# 0.251220584129346
# 0.001 1294194.226673853
# time elapsed in root finding: 189.97767806053162
# for pressure in: 5.72e+35, density is 1.79e+15, edens: 1.79e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.89, grav. mass: 2.20, bary. mass: 2.87, yp: 1.471106811596135
# 0.2523236895270856
# 0.001 1289247.656218076
# time elapsed in root finding: 192.0010859966278
# for pressure in: 5.88e+35, density is 1.81e+15, edens: 1.81e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.85, grav. mass: 2.20, bary. mass: 2.88, yp: 1.483931060484064
# 0.25346485671133634
# 0.001 1284537.5251550274
# time elapsed in root finding: 193.88790249824524
# for pressure in: 6.05e+35, density is 1.84e+15, edens: 1.84e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.80, grav. mass: 2.21, bary. mass: 2.89, yp: 1.4966773943979728
# 0.25456139319187937
# 0.001 1279773.1630537675
# time elapsed in root finding: 194.76202201843262
# for pressure in: 6.22e+35, density is 1.86e+15, edens: 1.86e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.75, grav. mass: 2.21, bary. mass: 2.89, yp: 1.5099733857800919
# 0.2556337151789366
# 0.001 1274946.56296875
# time elapsed in root finding: 196.81187510490417
# for pressure in: 6.40e+35, density is 1.89e+15, edens: 1.89e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.70, grav. mass: 2.21, bary. mass: 2.90, yp: 1.5230942092059712
# 0.2567171246756397
# 0.001 1270195.9607768403
# time elapsed in root finding: 198.06359553337097
# for pressure in: 6.58e+35, density is 1.92e+15, edens: 1.92e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.65, grav. mass: 2.21, bary. mass: 2.91, yp: 1.5360630042794448
# 0.2578099488129422
# 0.001 1265493.872531154
# time elapsed in root finding: 199.57894492149353
# for pressure in: 6.77e+35, density is 1.94e+15, edens: 1.94e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.61, grav. mass: 2.21, bary. mass: 2.91, yp: 1.5492790803761753
# 0.25888171532390786
# 0.001 1260768.2314831687
# time elapsed in root finding: 201.66696310043335
# for pressure in: 6.96e+35, density is 1.97e+15, edens: 1.97e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.56, grav. mass: 2.21, bary. mass: 2.92, yp: 1.562878463606591
# 0.25993918664113147
# 0.001 1255854.6627967444
# time elapsed in root finding: 203.5841269493103
# for pressure in: 7.16e+35, density is 2.00e+15, edens: 2.00e+15, Gamma:2.0 and sound speed: 0.00e+00
# FINAL: rstar: 12.51, grav. mass: 2.21, bary. mass: 2.92, yp: 1.5762199646832207
# 0.26097277320367646
# time elapsed: 0.09595394134521484
# {'rad': array([16.99076944, 16.95264499, 16.91613309, 16.87779713, 16.840666  ,
#        16.80182922, 16.76435594, 16.72353207, 16.68696687, 16.64639866,
#        16.60708975, 16.56720991, 16.52848114, 16.48951394, 16.44884171,
#        16.40852371, 16.3690162 , 16.32795583, 16.28678636, 16.24430598,
#        16.20370358, 16.16113548, 16.11816224, 16.07802825, 16.03477097,
#        15.9922485 , 15.9501632 , 15.90643366, 15.86302283, 15.81979447,
#        15.7758478 , 15.73214304, 15.68814596, 15.643867  , 15.59978631,
#        15.5547473 , 15.51056147, 15.46498046, 15.41900588, 15.37525636,
#        15.32986641, 15.28366514, 15.23802515, 15.19146417, 15.1448748 ,
#        15.09976181, 15.05410513, 15.00739681, 14.96044673, 14.9137498 ,
#        14.86640267, 14.82008005, 14.77278272, 14.7248506 , 14.67808222,
#        14.63152035, 14.58359057, 14.53621898, 14.48757407, 14.43995968,
#        14.39272086, 14.34381244, 14.29556665, 14.24734707, 14.19970642,
#        14.15136755, 14.10321395, 14.05529331, 14.00656886, 13.95759961,
#        13.91008599, 13.86150018, 13.81302297, 13.76434899, 13.71566862,
#        13.6672689 , 13.6183792 , 13.56992888, 13.52137482, 13.47315302,
#        13.42438676, 13.37563348, 13.32746631, 13.2790732 , 13.23049429,
#        13.18230635, 13.13441954, 13.08651527, 13.03843562, 12.99044205,
#        12.94194227, 12.89247656, 12.84537525, 12.79773163, 12.74946563,
#        12.70195961, 12.65493873, 12.60768231, 12.55854663, 12.51208461]), 'mg': array([1.5460351 , 1.55699255, 1.56794213, 1.57900089, 1.5900081 ,
#        1.60084516, 1.61183227, 1.62208965, 1.63343805, 1.64363387,
#        1.65465853, 1.66525046, 1.67589123, 1.68683381, 1.69734999,
#        1.70785349, 1.71831537, 1.72866124, 1.7389741 , 1.74912353,
#        1.75952421, 1.76939253, 1.77924006, 1.78951074, 1.79936345,
#        1.80908483, 1.81888763, 1.82856248, 1.83800497, 1.84761298,
#        1.85693823, 1.86611935, 1.87538004, 1.88455561, 1.89353363,
#        1.90245766, 1.91126586, 1.92000446, 1.92848429, 1.93705295,
#        1.94552168, 1.95383836, 1.96203704, 1.96989306, 1.97785205,
#        1.98591061, 1.99363167, 2.00120065, 2.00873219, 2.01609899,
#        2.02312286, 2.03046158, 2.0374455 , 2.0441627 , 2.05095911,
#        2.05762966, 2.06400712, 2.07044626, 2.07658184, 2.08266699,
#        2.08866614, 2.09439633, 2.0999936 , 2.10553367, 2.11096962,
#        2.1162061 , 2.12131337, 2.12635463, 2.13119939, 2.13579733,
#        2.14037802, 2.14476823, 2.14921321, 2.15317679, 2.15714713,
#        2.1610153 , 2.16473221, 2.16829009, 2.17169663, 2.17498217,
#        2.17815435, 2.18110601, 2.1840166 , 2.18669605, 2.18926249,
#        2.19172361, 2.19400181, 2.19619525, 2.19819035, 2.20008532,
#        2.20182997, 2.20304555, 2.20492412, 2.20624957, 2.20718743,
#        2.20828268, 2.20947361, 2.21037385, 2.21075308, 2.21133211]), 'mb': array([1.73713   , 1.75168355, 1.76627359, 1.78103196, 1.79579136,
#        1.810413  , 1.82526175, 1.83933653, 1.85469561, 1.86880778,
#        1.8839063 , 1.89857564, 1.91335413, 1.92853319, 1.94328165,
#        1.95807136, 1.97286941, 1.98758673, 2.00233306, 2.01693949,
#        2.03189293, 2.04630127, 2.06073346, 2.07571113, 2.09026603,
#        2.10472248, 2.11933609, 2.13385156, 2.14816423, 2.16271802,
#        2.17700589, 2.19117961, 2.20550244, 2.21978252, 2.23389215,
#        2.24799216, 2.26201283, 2.2760072 , 2.28975735, 2.30366192,
#        2.317503  , 2.33122114, 2.34485565, 2.35814675, 2.37160482,
#        2.38522264, 2.39850377, 2.41165995, 2.4248146 , 2.4378283 ,
#        2.45049992, 2.4635636 , 2.47626951, 2.48871557, 2.50128803,
#        2.51375618, 2.52593498, 2.53821076, 2.55018185, 2.56213013,
#        2.57401551, 2.58562522, 2.59712794, 2.60857624, 2.61993884,
#        2.63110632, 2.64215338, 2.65315931, 2.66395732, 2.67448842,
#        2.68503028, 2.69539814, 2.70580796, 2.71570578, 2.72562045,
#        2.73544445, 2.74510768, 2.75459662, 2.76391958, 2.77312176,
#        2.78221358, 2.79103879, 2.79984529, 2.80837071, 2.81677939,
#        2.82507332, 2.83315271, 2.84114155, 2.84889208, 2.8565334 ,
#        2.86399312, 2.87083474, 2.8785108 , 2.88539348, 2.89189493,
#        2.89856811, 2.90533112, 2.91175829, 2.91756951, 2.923575  ]), 'lambda': array([1420.32749323, 1340.29234106, 1265.61195293, 1194.11367971,
#        1127.52229327, 1064.63524843, 1005.55507525,  950.47692528,
#         897.40028292,  848.66577282,  801.31516635,  757.42172183,
#         716.21558361,  676.8137156 ,  639.89926577,  605.15885468,
#         572.58873831,  541.64261931,  512.50755829,  484.87602647,
#         458.85745188,  434.52495619,  411.41794456,  389.64565169,
#         368.97150742,  349.59413869,  331.29522501,  313.83165002,
#         297.54036693,  281.99436551,  267.39617003,  253.64171101,
#         240.55639784,  228.17625281,  216.57106183,  205.49668243,
#         195.11006438,  185.18409358,  175.82447165,  167.07258725,
#         158.70354802,  150.74844553,  143.25117969,  136.18838943,
#         129.44647471,  123.10025258,  117.11329199,  111.40513686,
#         105.9779399 ,  100.85880645,   96.02043663,   91.41146173,
#          87.04453746,   82.90883354,   78.99549305,   75.29274235,
#          71.76135292,   68.40798979,   65.21390275,   62.20102342,
#          59.34509507,   56.611905  ,   54.02738363,   51.5745507 ,
#          49.25273747,   47.03775817,   44.93662117,   42.93525385,
#          41.0260919 ,   39.21876401,   37.51310857,   35.87243829,
#          34.30624849,   32.83540722,   31.42581045,   30.0840175 ,
#          28.80083272,   27.5865858 ,   26.4297001 ,   25.32958942,
#          24.27229319,   23.27087921,   22.31570206,   21.40844289,
#          20.53909739,   19.71176341,   18.92719091,   18.17533664,
#          17.45873785,   16.77316831,   16.11475987,   15.49204625,
#          14.88436886,   14.31939374,   13.77955131,   13.25941645,
#          12.75864145,   12.28200622,   11.8247836 ,   11.39483361])}
# "for i,r in enumerate(r_arr):\n    #print(f'iteration:{i}, radial coordinate: {r_arr[i]}')\n\n    y_old = y_new\n    #[P, m, m_baryon, yp] = y_old\n    #print(f'OLD: pressure: {P:1.2e}, grav. mass: {m:1.2e}, bary. mass: {m_baryon:1.2e}, yp: {yp}')\n    dr=r_arr[i+1]-r_arr[i]\n    #print(f'dr: {dr:1.2e}')\n    #print(tov(y,r))\n    [dPdr, dmdr, dm_baryondr,dypdr] = tov(r,y_old)\n    #print(f'dPdr:{dPdr:1.2e},dmdr:{dmdr:1.2e},dm_baryondr:{dm_baryondr:1.2e},dypdr:{dypdr:1.2e}')\n    #print(dr*np.array([dPdr, dmdr, dm_baryondr,dypdr]))\n    y_new=y_old+dr*np.array([dPdr, dmdr, dm_baryondr,dypdr])\n    [P, m, m_baryon, yp] = y_new\n    #print(f'NEW: pressure: {P:1.2e}, grav. mass: {m:1.2e}, bary. mass: {m_baryon:1.2e}, yp: {yp}')\n\n    pmin=Pc*1.e-11\n    if(P<pmin):\n        print(f'radius: {r/1.e5} km, mass: {m/const.CGS_MSUN} solar mass')\n        sys.exit()"

# %%
plt.plot(rad_seq,mg_seq)
plt.grid()
plt.show()

# %% [markdown]
# ## Older material

# %%
#blh=np.loadtxt('./eos_tables/sfho+BL_01-Apr-2019.lorene',comments='#')
blh=np.loadtxt('./eos_tables/BLH_new_14-Apr-2020.lorene',comments='#')
blq=np.loadtxt('./eos_tables/BLQ_gibbs_180_10-Mar-2020.lorene',comments='#',skiprows=8)
alf2=np.loadtxt('./eos_tables/ALF2_data.out',comments='#')

#print(ds[:,1])
rho, edens, p = (blh[:,1],blh[:,2],blh[:,3])
print(const.CGS_AMU)
fm=1.e-13 #1femotometer in cm
dens_conversion=const.CGS_AMU/(fm**3)
edens_conversion=const.CGS_C**2

p_new=np.logspace(14,36,500)


tic = time.perf_counter()


for p in p_new:
    rho_new,edens_new,gamma_new=eos_from_pres(p_new,'./eos_tables/BLQ_gibbs_180_10-Mar-2020.lorene')

toc = time.perf_counter() 

print(f"time taken is {toc - tic:0.4f} seconds")

tic = time.perf_counter()

rho_new,edens_new,gamma_new=eos_from_pres(p_new,'./eos_tables/BLQ_gibbs_180_10-Mar-2020.lorene')
toc = time.perf_counter() 

print(f"time taken is {toc - tic:0.4f} seconds")



key='BLQ'
rho_new,edens_new,gamma_new=eos_from_pres(p_new,'./eos_tables/BLQ_gibbs_180_10-Mar-2020.lorene') #returns in cgs
index=np.array([int(i) for i in range(len(p_new))])
np.savetxt(f'./eos_tables/{key}_data.out',np.c_[index, rho_new/dens_conversion, edens_new/edens_conversion, p_new, gamma_new],header='\n#i rho edens pres gamma',comments=f'#density, pressure and energy density in cgs units for eos={key}.\n')

key='BLH'
rho_new,edens_new,gamma_new=eos_from_pres(p_new,'./eos_tables/BLH_new_14-Apr-2020.lorene') #returns in cgs
index=np.array([int(i) for i in range(len(p_new))])
np.savetxt(f'./eos_tables/{key}_data.out',np.c_[index, rho_new/dens_conversion, edens_new/edens_conversion, p_new, gamma_new],header='\n#i rho edens pres gamma',comments=f'#density, pressure and energy density in cgs units for eos={key}.\n')




blh=np.loadtxt('./eos_tables/BLH_data.out',comments='#')
blq=np.loadtxt('./eos_tables/BLQ_data.out',comments='#')
               
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(12,12))
ax1.plot(blh[:,1]*dens_conversion,blh[:,3],label='BLH')
ax1.plot(rho_new,p_new,label='interpolated')
ax1.plot(blq[:,1]*dens_conversion,blq[:,3],label='BLQ')
ax1.plot(alf2[:,1]*dens_conversion,alf2[:,3],label='ALF2')
ax1.set_xlim([1.e14,1.e16])
ax1.set_ylim([1.e32,1.e36])
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set(xlabel=r'mass density ($g/cm^{3}$)',ylabel=r'pressure ($dyne/cm^2$)')
ax1.legend(loc=4)

ax2.plot(blh[:,1]*dens_conversion,blh[:,2]*edens_conversion,label='BLH')
ax2.plot(rho_new,edens_new,label='interpolated')
ax2.plot(blq[:,1]*dens_conversion,blq[:,2]*edens_conversion,label='BLQ')
ax2.plot(alf2[:,1]*dens_conversion,alf2[:,2]*edens_conversion,label='ALF2')
ax2.set_xlim([1.e14,1.e16])
ax2.set_ylim([1.e34,1.e37])
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set(xlabel=r'mass density ($g/cm^{3}$)',ylabel=r'edens ($erg/cm^{3}$)')
ax2.legend(loc=4)

ax3.plot(rho_new,gamma_new,label='BLH')
ax3.plot(blh[:,1]*dens_conversion,blh[:,4],label='BLH interpolated')
ax3.plot(alf2[:,1]*dens_conversion,alf2[:,4],label='ALF2')
ax3.set_xscale('log')
ax3.legend()

plt.tight_layout()
#plt.savefig('eos_plots_phase.png',dpi=150)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-23ab6b7400ae> in <module>
#       1 #blh=np.loadtxt('./eos_tables/sfho+BL_01-Apr-2019.lorene',comments='#')
# ----> 2 blh=np.loadtxt('./eos_tables/BLH_new_14-Apr-2020.lorene',comments='#')
#       3 blq=np.loadtxt('./eos_tables/BLQ_gibbs_180_10-Mar-2020.lorene',comments='#',skiprows=8)
#       4 alf2=np.loadtxt('./eos_tables/ALF2_data.out',comments='#')
#       5
#
# NameError: name 'np' is not defined

# %%
from scipy.integrate import solve_ivp
def exponential_decay(t, y): return -0.5 * y

def shm(t,y): 
    return [-y[0]**2,y[1]]

t_eval=np.linspace(0,10,100)
#sol = solve_ivp(exponential_decay, [0, 10], [2])
sol = solve_ivp(shm, [0, 10], [2,4],method='RK45',t_eval=t_eval)
#print(sol.t)


print(sol.y)

plt.plot(sol.t,sol.y[0],sol.y[1])
plt.yscale('log')
plt.show()
# Out:
# [[2.00000000e+00 1.66353802e+00 1.42325529e+00 1.24751440e+00
#   1.11053889e+00 9.98290986e-01 9.06967371e-01 8.31355758e-01
#   7.67231265e-01 7.11907115e-01 6.64041986e-01 6.22401117e-01
#   5.85874874e-01 5.53478744e-01 5.24353340e-01 4.97937132e-01
#   4.74017834e-01 4.52317187e-01 4.32575284e-01 4.14551162e-01
#   3.98022801e-01 3.82787125e-01 3.68659999e-01 3.55476235e-01
#   3.43142473e-01 3.31622931e-01 3.20852287e-01 3.10768750e-01
#   3.01314067e-01 2.92433522e-01 2.84075935e-01 2.76193663e-01
#   2.68742602e-01 2.61682184e-01 2.54975379e-01 2.48588692e-01
#   2.42498649e-01 2.36696504e-01 2.31164884e-01 2.25886867e-01
#   2.20846400e-01 2.16028304e-01 2.11418271e-01 2.07002863e-01
#   2.02769517e-01 1.98706537e-01 1.94803102e-01 1.91049261e-01
#   1.87435935e-01 1.83954918e-01 1.80599083e-01 1.77362768e-01
#   1.74240210e-01 1.71225834e-01 1.68314317e-01 1.65500582e-01
#   1.62779800e-01 1.60147389e-01 1.57599018e-01 1.55130601e-01
#   1.52738301e-01 1.50418530e-01 1.48167946e-01 1.45983455e-01
#   1.43862214e-01 1.41801581e-01 1.39798984e-01 1.37852110e-01
#   1.35958749e-01 1.34116776e-01 1.32324152e-01 1.30578922e-01
#   1.28879216e-01 1.27223250e-01 1.25609322e-01 1.24035818e-01
#   1.22501207e-01 1.21004045e-01 1.19542970e-01 1.18116708e-01
#   1.16724065e-01 1.15363846e-01 1.14034930e-01 1.12736281e-01
#   1.11466899e-01 1.10225816e-01 1.09012100e-01 1.07824852e-01
#   1.06663207e-01 1.05526337e-01 1.04413445e-01 1.03323770e-01
#   1.02256585e-01 1.01211198e-01 1.00186949e-01 9.91832137e-02
#   9.81993995e-02 9.72349136e-02 9.62891893e-02 9.53616844e-02]
#  [4.00000000e+00 4.42515193e+00 4.89549384e+00 5.41582267e+00
#   5.99145919e+00 6.62828869e+00 7.33279079e+00 8.11217015e+00
#   8.97439945e+00 9.92833895e+00 1.09836225e+01 1.21509788e+01
#   1.34424120e+01 1.48712009e+01 1.64518996e+01 1.82008868e+01
#   2.01358072e+01 2.22758084e+01 2.46427393e+01 2.72611533e+01
#   3.01583086e+01 3.33641678e+01 3.69113981e+01 4.08353715e+01
#   4.51781028e+01 4.99830606e+01 5.52953066e+01 6.11677020e+01
#   6.76609086e+01 7.48433888e+01 8.27914052e+01 9.15890212e+01
#   1.01328101e+02 1.12108307e+02 1.24037107e+02 1.37229764e+02
#   1.51825376e+02 1.67982994e+02 1.85844180e+02 2.05578581e+02
#   2.27385313e+02 2.51492954e+02 2.78159547e+02 3.07672602e+02
#   3.40349091e+02 3.76535455e+02 4.16607596e+02 4.60970883e+02
#   5.10060150e+02 5.64339695e+02 6.24363020e+02 6.90835072e+02
#   7.64321193e+02 8.45494583e+02 9.35157170e+02 1.03423961e+03
#   1.14380130e+03 1.26503034e+03 1.39924360e+03 1.54788664e+03
#   1.71253376e+03 1.89488802e+03 2.09678117e+03 2.32017370e+03
#   2.56715485e+03 2.84020797e+03 3.14264487e+03 3.47700924e+03
#   3.84630937e+03 4.25415464e+03 4.70475553e+03 5.20292361e+03
#   5.75407158e+03 6.36421322e+03 7.03996340e+03 7.78853812e+03
#   8.61775445e+03 9.53603059e+03 1.05523858e+04 1.16764405e+04
#   1.29184874e+04 1.42937359e+04 1.58155496e+04 1.74968318e+04
#   1.93533796e+04 2.14038840e+04 2.36699299e+04 2.61759961e+04
#   2.89494550e+04 3.20205731e+04 3.54225109e+04 3.91913223e+04
#   4.33659555e+04 4.79882522e+04 5.31029484e+04 5.87576735e+04
#   6.50047935e+04 7.19140420e+04 7.95575761e+04 8.80135856e+04]]

# %%
#m_arr,r_arr,rhoc_arr,mb_arr,yp_arr=mass_radius()
ind=190
#print('m_arr = \n',m_arr[0:ind])
#print('r_arr = \n',len(r_arr[0:ind]),r_arr[0:ind])
#print('yp_arr = \n',yp_arr[0:ind])
#np.save('./eos_tables/BLH',[m_arr[0:ind],r_arr[0:ind],rhoc_arr[0:ind],mb_arr[0:ind],yp_arr[0:ind]])
#np.savetxt(f'./eos_tables/BLH_M_R_Mb_Lam.out',np.c_[m_arr[0:ind],r_arr[0:ind],rhoc_arr[0:ind],mb_arr[0:ind],yp_arr[0:ind]],header='#Mass Radius Baryonic_Mass Lambda \n',comments=f'#Mass(in solar mass), Radius(km), BaryonicMass(solar mass), Lambda(dimensional).\n')
blh_data=np.load('./eos_tables/BLH.npy',allow_pickle=True) 
print(len(blh_data[2]))
# Out:
# 147

# %%
blq=np.load('../EOS_data/BLQ')
np.savetxt(f'../EOS_Data/BLQ_M_R_Mb_Lam.out',np.c_[m_arr[0:ind],r_arr[0:ind],rhoc_arr[0:ind],mb_arr[0:ind],yp_arr[0:ind]],header='#Mass Radius Baryonic_Mass Lambda \n',comments=f'#Mass(in solar mass), Radius(km), BaryonicMass(solar mass), Lambda(dimensional).\n')

# %%
data_path='./m_mB_rad_data'
#data_path='../data/m_mB_rad_data'
#eos_list=['MS1','APR3','APR4','DD2','SLy','ALF2','BLQ']
eos_list=['BLQ','ALF2','BLH']

fig,((ax1,ax2))=plt.subplots(nrows=1,ncols=2,figsize=(12,6))
for eos in eos_list:
    ds=np.load(f'{data_path}/%s.npy'%eos,allow_pickle=True) #0:mass(msun), 1:radius(km), 2:rhoc(cgs), 4:lambda (in cgs)

    print(f'length of mass-radius points={len(ds[4])} in eos={eos}')
    #print(max(ds[0]))
    ax1.plot(ds[1],ds[0],label=eos)
    #ax1.plot(ds[1],ds[3],ls='--',label='mBaryonic')
    ax1.set(xlabel='radius (km)',ylabel='mass (solar mass)')
    ax1.legend()
    #plt.xlim([0.5,3.0])
    #plt.ylim([10,1.e6])
    #plt.clf()
    ax2.semilogy(ds[0],(ds[4]*const.CGS_G)*((const.CGS_C**2)/(const.CGS_G*ds[0]*const.CGS_MSUN))**5,label=eos)   #(lambda_out*const.CGS_G)*((const.CGS_C**2)/(const.CGS_G*mass_input*const.CGS_MSUN))**5
    ax2.legend()
    ax2.set(xlabel='mass (solar mass)',ylabel='dimensionless Lambda')
plt.xlabel('mass')
plt.ylabel(r'$\Lambda$')
#plt.savefig('blh_blq_mass-radius.png',dpi=150)
plt.show()
# Out:
# length of mass-radius points=200 in eos=BLQ
# length of mass-radius points=291 in eos=ALF2
# length of mass-radius points=147 in eos=BLH
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-afb77717a91f> in <module>
#      10     print(f'length of mass-radius points={len(ds[4])} in eos={eos}')
#      11     #print(max(ds[0]))
# ---> 12     ax1.plot(ds[1],ds[0],label=eos)
#      13     #ax1.plot(ds[1],ds[3],ls='--',label='mBaryonic')
#      14     ax1.set(xlabel='radius (km)',ylabel='mass (solar mass)')
#
# ~/sw/anaconda3/envs/gw_py377/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~/sw/anaconda3/envs/gw_py377/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~/sw/anaconda3/envs/gw_py377/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (147,)

# %%
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
import numpy as np
    
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':20,
         'ytick.labelsize':20}
pylab.rcParams.update(params)


from cycler import cycler

#eos_data_path='../../../GRMHDResearch/_kilonovae_standardization/codes/src/tov/m_mB_rad_data'

eos_data_path='./m_mB_rad_data'
#data_path='../data/m_mB_rad_data'
#eos_list=['MS1','APR4','DD2','SLy','ALF2','H4'] #'APR3',
eos_list=['APR4','ALF2'] #,'APR3']

#['BLH','BLQ','H4','MPA1','MS1','SLy','WFF1','WFF2',]

#available Matlab sequences: 'MS1','APR4','DD2','SLy','ALF2',H4

sebastiano_data='./matlab_Sebastiano/tov/Sequences/Complete/'



#fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2,figsize=(24,16))
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,figsize=(16,8))
legend_labelsize=12
xy_labelsize=12
custom_cycler = (cycler(color=['r', 'b', 'g', 'k','c','orange'])) #+ cycler(lw=[1, 2, 3, 4]))

#plt.rc('lines', linewidth=4)
#plt.rc('axes', prop_cycle=custom_cycler)

#fig.gca().set_color_cycle(['red', 'green', 'blue', 'yellow'])

#fig.suptitle('M-R relation')
for cc,eos in zip(custom_cycler,eos_list):
    print(cc['color'])
    file=sebastiano_data+eos+'_sequence.txt'  
    print(file)
    ds_matlab=np.loadtxt(file,skiprows=1)
    ax1.plot(ds_matlab[:,3]*const.AGEO_LENGTH_IN_M/1.e3,ds_matlab[:,1],'x',color=cc['color'],label=eos+'matlab')
    
    
    
    ds=np.load(f'{eos_data_path}/%s.npy'%eos) #0:mass(msun), 1:radius(km), 2:rhoc(cgs), 3: baryonic mass, 4:lambda (in cgs)
    print(f'length of mass-radius points={len(ds[4])} in eos={eos}')
    #print(max(ds[0]))
    print(ds[1])
    ax1.plot(ds[1],ds[0],color=cc['color'],lw=2,label=eos)
    #ax1.plot(ds[1],ds[3],color=cc['color'],ls='--',lw=2,label=eos+'M_Baryonic')
    
    
    m_new=np.linspace(0.5,1.9,100)
    C_arr,l_arr,r_arr=Compactness_MBaryon(m_new,eos)
    
    #ax1.plot(r_arr,m_new,'x',label='interpolated '+eos)
    ax1.set_xlabel(r'Radius (km)',fontsize=xy_labelsize)
    ax1.set_ylabel(r'Mass ($M_\odot$)',fontsize=xy_labelsize)
    ax1.set_xlim([8.5,16])
    ax1.legend(fontsize=legend_labelsize)
    ax1.grid(True)

    #ax3.plot(abs(ds[1]-r_arr)/ds[1],ds[0],'.',label=eos)
    #ax3.set(ylabel='mass',xlabel='relative interpolation error in radius')
    #ax3.set_xscale('log')
    #ax3.legend()
    
    ax2.semilogy(ds_matlab[:,1],ds_matlab[:,6],'x',color=cc['color'],label=eos+'_matlab, Bernuzzi et. al.')
    ax2.semilogy(ds[0],(ds[4]*const.CGS_G)*((const.CGS_C**2)/(const.CGS_G*ds[0]*const.CGS_MSUN))**5,color=cc['color'],lw=2,label=eos)   #(lambda_out*const.CGS_G)*((const.CGS_C**2)/(const.CGS_G*mass_input*const.CGS_MSUN))**5
    #ax2.semilogy(ds[0],ds[4],label=eos)
    #ax2.semilogy(m_new,l_arr,'x',label=f'interpolated {eos}')
    ax2.set_xlabel(r'Mass ($M_\odot$)',fontsize=xy_labelsize)
    ax2.set_ylabel(r'Tidal deformability, $\Lambda $',fontsize=xy_labelsize) #(g/cm^2/s^2)
    ax2.set_xlim([0.4,2.4])
    ax2.set_ylim([1,1.e6])
    ax2.legend(fontsize=legend_labelsize)
    ax2.grid(True)
            
    #ax3.plot(ds[0],ds[2],label=eos)
    
    #ax4.plot(ds[0],ds[3],label=eos)
ax1.set_prop_cycle(custom_cycler)
#plt.grid()
plt.tight_layout()
#plt.savefig('./data/m_mB_rad_data/plots/MR_eos.png',dpi=150)
plt.show()
# Out:
# r
# ./matlab_Sebastiano/tov/Sequences/Complete/APR4_sequence.txt
# length of mass-radius points=298 in eos=APR4
# [18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  17.87393704 17.22561324 16.65832991 16.14507357 15.68584421 15.27163733
#  14.90245295 14.56928655 14.27213814 14.00200322 13.7498773  13.52476487
#  13.31766143 13.13757149 12.96648604 12.81340958 12.66933763 12.54327467
#  12.4262162  12.31816224 12.21911277 12.1200633  12.03902282 11.96698684
#  11.89495087 11.82291489 11.75087891 11.68784743 11.63382045 11.57979346
#  11.53477098 11.49875299 11.47173949 11.444726   11.41771251 11.39970352
#  11.38169452 11.37269003 11.36368553 11.35468103 11.35468103 11.34567653
#  11.34567653 11.34567653 11.34567653 11.34567653 11.34567653 11.33667204
#  11.33667204 11.33667204 11.32766754 11.32766754 11.31866304 11.30965854
#  11.30065405 11.29164955 11.27364056 11.25563156 11.23762257 11.21961357
#  11.20160458 11.17459109 11.14757759 11.1205641  11.08454611 11.04852812
#  11.01251014 10.97649215 10.93146966 10.89545167 10.85042918 10.7964022
#  10.75137971 10.69735273 10.64332575 10.58929876 10.53527178 10.4812448
#  10.41821332 10.36418633 10.30115485 10.23812337 10.17509189 10.11206041
#  10.04902893  9.98599745  9.92296597  9.85993449]
# b
# ./matlab_Sebastiano/tov/Sequences/Complete/ALF2_sequence.txt
# length of mass-radius points=38 in eos=ALF2
# [18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         18.         18.         18.         18.
#  18.         18.         16.14414415 12.73873874 12.1981982  12.45045045
#  12.64864865 12.68468469 12.57657658 12.32432433 12.05405406 11.71171172
#  11.31531532 10.9009009 ]

# %%
sebastiano_data='./matlab_Sebastiano/tov/Sequences/Complete/'
files=glob.glob(sebastiano_data+'/*txt')
print(files)

for f in files:
    eos=f.split(sebastiano_data)[1].split('.txt')[0].split('_sequence')[0]
    file=sebastiano_data+eos+'_sequence.txt'
    ds=np.loadtxt(file,skiprows=1)
    plt.plot(1.4*ds[:,3],ds[:,2],label=eos)
#plt.legend()
plt.show()
# Out:
# ['./matlab_Sebastiano/tov/Sequences/Complete/2B_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/2H_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/ALF2_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/APR4_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/BHBlp_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/BLh_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/DD2_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/ENG_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/H3_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/H4_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/HB_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/LS200_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/MPA1_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/MS1b_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/MS1_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/SFHo_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/SLy_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/TM1_sequence.txt', './matlab_Sebastiano/tov/Sequences/Complete/TMA_sequence.txt']
